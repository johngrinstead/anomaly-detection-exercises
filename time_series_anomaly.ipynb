# %%
import numpy as np
import pandas as pd
import math
from sklearn import metrics

from scipy.stats import entropy

import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import matplotlib.dates as mdates #to format dates on our plots
# %matplotlib inline
import seaborn as sns

# %%
import env

# %%
def get_connection(db, user=env.user, host=env.host, password=env.password):
    return f'mysql+pymysql://{user}:{password}@{host}/{db}'

# %%
sql = '''
select *
from logs
join cohorts on logs.cohort_id = cohorts.id;
'''

# %%
df = pd.read_sql(sql, get_connection('curriculum_logs'))

# %%
df.head(10)
# Out:
#          date      time                                 path  user_id  \
# 0  2018-01-26  09:55:03                                    /        1
# 1  2018-01-26  09:56:02                              java-ii        1
# 2  2018-01-26  09:56:05  java-ii/object-oriented-programming        1
# 3  2018-01-26  09:56:06   slides/object_oriented_programming        1
# 4  2018-01-26  09:56:24            javascript-i/conditionals        2
# 5  2018-01-26  09:56:41                   javascript-i/loops        2
# 6  2018-01-26  09:56:46            javascript-i/conditionals        3
# 7  2018-01-26  09:56:48               javascript-i/functions        3
# 8  2018-01-26  09:56:59                   javascript-i/loops        2
# 9  2018-01-26  09:58:26               javascript-i/functions        4
#
#    cohort_id            ip  id     name     slack  start_date    end_date  \
# 0        8.0  97.105.19.61   8  Hampton  #hampton  2015-09-22  2016-02-06
# 1        8.0  97.105.19.61   8  Hampton  #hampton  2015-09-22  2016-02-06
# 2        8.0  97.105.19.61   8  Hampton  #hampton  2015-09-22  2016-02-06
# 3        8.0  97.105.19.61   8  Hampton  #hampton  2015-09-22  2016-02-06
# 4       22.0  97.105.19.61  22    Teddy    #teddy  2018-01-08  2018-05-17
# 5       22.0  97.105.19.61  22    Teddy    #teddy  2018-01-08  2018-05-17
# 6       22.0  97.105.19.61  22    Teddy    #teddy  2018-01-08  2018-05-17
# 7       22.0  97.105.19.61  22    Teddy    #teddy  2018-01-08  2018-05-17
# 8       22.0  97.105.19.61  22    Teddy    #teddy  2018-01-08  2018-05-17
# 9       22.0  97.105.19.61  22    Teddy    #teddy  2018-01-08  2018-05-17
#
#             created_at           updated_at deleted_at  program_id
# 0  2016-06-14 19:52:26  2016-06-14 19:52:26       None           1
# 1  2016-06-14 19:52:26  2016-06-14 19:52:26       None           1
# 2  2016-06-14 19:52:26  2016-06-14 19:52:26       None           1
# 3  2016-06-14 19:52:26  2016-06-14 19:52:26       None           1
# 4  2018-01-08 13:59:10  2018-01-08 13:59:10       None           2
# 5  2018-01-08 13:59:10  2018-01-08 13:59:10       None           2
# 6  2018-01-08 13:59:10  2018-01-08 13:59:10       None           2
# 7  2018-01-08 13:59:10  2018-01-08 13:59:10       None           2
# 8  2018-01-08 13:59:10  2018-01-08 13:59:10       None           2
# 9  2018-01-08 13:59:10  2018-01-08 13:59:10       None           2

# %%
df.shape
# Out:
# (900223, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 900223 entries, 2018-01-26 09:55:03 to 2021-04-21 16:44:39
# Data columns (total 4 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   page_viewed  900222 non-null  object
#  1   user_id      900223 non-null  int64
#  2   cohort_id    847330 non-null  float64
#  3   ip           900223 non-null  object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 34.3+ MB

# %%
df.describe()
# Out:
#              user_id      cohort_id
# count  900223.000000  847330.000000
# mean      458.825707      48.501049
# std       249.296767      32.795482
# min         1.000000       1.000000
# 25%       269.000000      28.000000
# 50%       475.000000      33.000000
# 75%       660.000000      57.000000
# max       981.000000     139.000000

# %%
df.isnull().sum()
# Out:
# page_viewed        1
# user_id            0
# cohort_id      52893
# ip                 0
# dtype: int64

# %%
df['cohort_id'] = df.cohort_id.fillna(0)

# %%
df.isnull().sum()
# Out:
# page_viewed    1
# user_id        0
# cohort_id      0
# ip             0
# dtype: int64

# %%
for col in df.columns:
    print(col)
    print(df[col].value_counts(),'\n')
# Out:
# page_viewed
# /                                        50313
# search/search_index.json                 19519
# javascript-i                             18983
# toc                                      18297
# java-iii                                 13733
#                                          ...
# 11-nlp/3-acquire/.json                       1
# 11-distributed-ml/6.2-prepare-part-2         1
# 4-stats/2.5-distributions-and-testing        1
# python                                       1
# jquery/whack-a-mole                          1
# Name: page_viewed, Length: 2313, dtype: int64
#
# user_id
# 11     17913
# 64     16347
# 53     12329
# 314     7783
# 1       7404
#        ...
# 952        1
# 212        1
# 940        1
# 649        1
# 879        1
# Name: user_id, Length: 981, dtype: int64
#
# cohort_id
# 28.0     84031
# 0.0      52893
# 33.0     40730
# 29.0     38096
# 62.0     37109
# 53.0     36902
# 24.0     35636
# 57.0     33844
# 56.0     33568
# 51.0     32888
# 59.0     32015
# 22.0     30926
# 58.0     29855
# 32.0     29356
# 23.0     28534
# 52.0     28033
# 26.0     27749
# 34.0     26538
# 25.0     25586
# 31.0     25359
# 132.0    23691
# 55.0     21582
# 27.0     20743
# 61.0     17713
# 134.0    16623
# 135.0    16397
# 133.0    14715
# 14.0      9587
# 1.0       8890
# 137.0     8562
# 21.0      7444
# 138.0     7276
# 17.0      4954
# 13.0      2845
# 18.0      2158
# 8.0       1712
# 139.0     1672
# 19.0      1237
# 16.0       755
# 15.0       691
# 7.0        598
# 12.0       302
# 11.0       253
# 2.0         93
# 6.0         72
# 9.0          5
# 4.0          4
# 5.0          1
# Name: cohort_id, dtype: int64
#
# ip
# 97.105.19.58       284579
# 97.105.19.61        61662
# 192.171.117.210      9515
# 71.150.217.33        6791
# 76.185.145.231       4754
#                     ...
# 172.58.110.231          1
# 174.255.138.88          1
# 172.58.30.200           1
# 107.77.222.90           1
# 99.203.143.2            1
# Name: ip, Length: 5531, dtype: int64
